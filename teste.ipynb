# %%
import pickle
with open('data/historico_nao_baixados.pkl','rb') as f:
    nao = pickle.load(f)
codigos = set(str(n['cod_prod']) for n in nao)
print(sorted(codigos))
print(len(nao))
# Out:
# ['27', '28', '29', '30', '31']
# 825
